# %%
# %config Completer.use_jedi = False
# %matplotlib widget

import pandas_datareader.data as web

import pandas as pd

import scipy as sp

import statistics

from datetime import datetime

import matplotlib.pyplot as plt

import plotly.graph_objects as go

import mplfinance as mpf

import numpy as np

import pymc3 as pm

import seaborn as sns

#import tensorflow as tf

# %%
df = web.DataReader('AAPL', 'yahoo', start='2021-01-01')

# %%
?
# Out:
# IPython -- An enhanced Interactive Python
# ...
#
# IPython offers a fully compatible replacement for the standard Python
# interpreter, with convenient shell features, special commands, command
# history mechanism and output results caching.
#
# At your system command line, type 'ipython -h' to see the command line
# options available. This document only describes interactive features.
#
# GETTING HELP
# ------------
#
# Within IPython you have various way to access help:
#
#   ?         -> Introduction and overview of IPython's features (this screen).
#   object?   -> Details about 'object'.
#   object??  -> More detailed, verbose information about 'object'.
#   %quickref -> Quick reference of all IPython specific syntax and magics.
#   help      -> Access Python's own help system.
#
# If you are in terminal IPython you can quit this screen by pressing `q`.
#
#
# MAIN FEATURES
# -------------
#
# * Access to the standard Python help with object docstrings and the Python
# ...

# %%
# %quickref
# Out:
# IPython -- An enhanced Interactive Python - Quick Reference Card
# ...
#
# obj?, obj??      : Get help, or more help for object (also works as
#                    ?obj, ??obj).
# ?foo.*abc*       : List names in 'foo' containing 'abc' in them.
# %magic           : Information about IPython's 'magic' % functions.
#
# Magic functions are prefixed by % or %%, and typically take their arguments
# without parentheses, quotes or even commas for convenience.  Line magics take a
# single % and cell magics are prefixed with two %%.
#
# Example magic function calls:
#
# %alias d ls -F   : 'd' is now an alias for 'ls -F'
# alias d ls -F    : Works if 'alias' not a python name
# alist = %alias   : Get list of aliases to 'alist'
# cd /usr/share    : Obvious. cd -<tab> to choose from visited dirs.
# %cd??            : See help AND source for magic %cd
# %timeit x=10     : time the 'x=10' statement with high precision.
# %%timeit x=2**100
# ...

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 8E12-B966
#
#  Directory of C:\Users\richa\PycharmProjects\jiushiwaner
#
# 05/02/2021  12:58 PM    <DIR>          .
# 05/02/2021  12:58 PM    <DIR>          ..
# 05/02/2021  12:56 PM    <DIR>          .idea
# 04/29/2021  04:28 PM    <DIR>          .ipynb_checkpoints
# 04/28/2021  11:31 PM             1,619 finmarketpy.log
# 04/29/2021  03:14 PM               423 main.py
# 05/02/2021  12:58 PM            35,986 Untitled.ipynb
#                3 File(s)         38,028 bytes
#                4 Dir(s)  42,061,369,344 bytes free

# %%
df['SMA1'] = df['Close'].rolling(window=50).mean()
df['SMA2'] = df['Close'].rolling(window=200).mean()

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  143301900.0
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900.0
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# 2021-01-07  131.630005  127.860001  128.360001  130.919998  109578200.0
# 2021-01-08  132.630005  130.229996  132.429993  132.050003  105158200.0
# ...                ...         ...         ...         ...          ...
# 2021-04-26  135.059998  133.559998  134.830002  134.720001   66905100.0
# 2021-04-27  135.410004  134.110001  135.009995  134.389999   66015800.0
# 2021-04-28  135.020004  133.080002  134.309998  133.580002  107760100.0
# 2021-04-29  137.070007  132.449997  136.470001  133.479996  151101000.0
# 2021-04-30  133.559998  131.070007  131.779999  131.460007  109713200.0
#
#              Adj Close      SMA1  SMA2
# Date
# 2021-01-04  129.216919       NaN   NaN
# ...

# %%
plt.figure(figsize=(10, 10))

plt.xlabel('Date')
plt.ylabel('Date')
plt.title('Close price')

plt.plot(df.index, df['Close'])
plt.plot(df['SMA1'], 'g--', label='SMA1')
plt.plot(df['SMA2'], 'r--', label='SMA2')

plt.legend()
plt.show( )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot([1,2,3], [3,6,9], 'go:', label='A')
plt.plot([1,2,3], [12,8,4], color='red', marker='H', label='B')

plt.xlabel('Shit')
plt.ylabel('Value')

plt.xlim(0, 10)
plt.ylim(0, 20)

plt.xticks([1,2,3])
plt.yticks([0,5,10,15,20])

plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3, projection='polar')
ax4 = fig.add_subplot(2,2,4)

fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mpf??
# Out:
# Type:        module
# String form: <module 'mplfinance' from 'C:\\ProgramData\\Anaconda3\\envs\\jiushiwaner\\lib\\site-packages\\mplfinance\\__init__.py'>
# File:        c:\programdata\anaconda3\envs\jiushiwaner\lib\site-packages\mplfinance\__init__.py
# Source:
# import mplfinance._mpf_warnings
# from   mplfinance.plotting  import plot, make_addplot
# from   mplfinance._styles   import make_mpf_style, make_marketcolors
# from   mplfinance._styles   import available_styles, write_style_file
# from   mplfinance._version  import __version__
# from   mplfinance._mplwraps import figure, show

# %%
mpf.plot(df, type='candle', figscale=1, volume=True,
        title='Apple',
        ylabel='Price')

mpf.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
